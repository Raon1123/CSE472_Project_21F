# %%
import numpy as np
import pickle

#from train_model import train_step, test_step
from models.decisiontree import DecisionTree, RandForest
from utils.load_data import get_data
from utils.make_dict import train_bow, get_bow

# %%
args ={'dataset': 'cifar10',
       'dataroot': './data',
       'model': 'custom_SVM',
       'kernel': 'gaussian',
       'validation': 0.1,
       'dict_size': 300,
       'load_cluster': False
       }

# %%
trainX, trainy = get_data(dataset=args['dataset'], train=True, dataroot=args['dataroot'])
if args['dataset'] == 'cifar10':
    trainX = trainX.reshape((-1, 32, 32, 3), order='F')

if args['load_cluster']:
    with open("./cluster.dump", "rb") as f:
        cluster = pickle.load(f)
else:
    cluster = train_bow(trainX, num_dict=args['dict_size'], num_select=10000)
    with open("./cluster.dump", "wb") as f:
        pickle.dump(cluster, f)

trainFeature = get_bow(trainX, cluster, num_dict=args['dict_size'])

# %%
model = RandForest(forest=10, bag_size=5000, depth=100)
#model = DecisionTree(depth=150)

# %%
model.fit(trainFeature, trainy)
# Out:
#   0%|          | 0/10 [06:25<?, ?it/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_7156/2523003416.py in <module>
# ----> 1 model.fit(trainFeature, trainy)
#
# c:\Users\MLV\OneDrive - UNIST\UNIST\2021_Fall\CSE472_컴퓨터비전\Vision_Framework\models\decisiontree.py in fit(self, X, y)
#     195             bag = np.random.randint(0, trainN, size=self.bag_size)
#     196             selection = np.random.choice(bag, size=trainN, replace=True)
# --> 197             tree.fit(X[selection,:], y[selection])
#     198
#     199         return self
#
# c:\Users\MLV\OneDrive - UNIST\UNIST\2021_Fall\CSE472_컴퓨터비전\Vision_Framework\models\decisiontree.py in fit(self, X, y)
#     106
#     107         samples = [X, y]
# --> 108         self.root = self.train_node(samples ,self.depth)
#     109
#     110         return self
#
# c:\Users\MLV\OneDrive - UNIST\UNIST\2021_Fall\CSE472_컴퓨터비전\Vision_Framework\models\decisiontree.py in train_node(self, samples, depth)
#     126         ret.push_left(self.train_node(left_data, depth-1))
#     127         if right_data[1].shape[0] != 0:
# --> 128             ret.push_right(self.train_node(right_data, depth-1))
#     129         else:
#     130             value, cnt = np.unique(y, return_counts=True)
#
# c:\Users\MLV\OneDrive - UNIST\UNIST\2021_Fall\CSE472_컴퓨터비전\Vision_Framework\models\decisiontree.py in train_node(self, samples, depth)
#     126         ret.push_left(self.train_node(left_data, depth-1))
#     127         if right_data[1].shape[0] != 0:
# --> 128             ret.push_right(self.train_node(right_data, depth-1))
#     129         else:
#     130             value, cnt = np.unique(y, return_counts=True)
#
# c:\Users\MLV\OneDrive - UNIST\UNIST\2021_Fall\CSE472_컴퓨터비전\Vision_Framework\models\decisiontree.py in train_node(self, samples, depth)
#     126         ret.push_left(self.train_node(left_data, depth-1))
#     127         if right_data[1].shape[0] != 0:
# --> 128             ret.push_right(self.train_node(right_data, depth-1))
#     129         else:
#     130             value, cnt = np.unique(y, return_counts=True)
#
# c:\Users\MLV\OneDrive - UNIST\UNIST\2021_Fall\CSE472_컴퓨터비전\Vision_Framework\models\decisiontree.py in train_node(self, samples, depth)
#     126         ret.push_left(self.train_node(left_data, depth-1))
#     127         if right_data[1].shape[0] != 0:
# --> 128             ret.push_right(self.train_node(right_data, depth-1))
#     129         else:
#     130             value, cnt = np.unique(y, return_counts=True)
#
# c:\Users\MLV\OneDrive - UNIST\UNIST\2021_Fall\CSE472_컴퓨터비전\Vision_Framework\models\decisiontree.py in train_node(self, samples, depth)
#     126         ret.push_left(self.train_node(left_data, depth-1))
#     127         if right_data[1].shape[0] != 0:
# --> 128             ret.push_right(self.train_node(right_data, depth-1))
#     129         else:
#     130             value, cnt = np.unique(y, return_counts=True)
#
# c:\Users\MLV\OneDrive - UNIST\UNIST\2021_Fall\CSE472_컴퓨터비전\Vision_Framework\models\decisiontree.py in train_node(self, samples, depth)
#     126         ret.push_left(self.train_node(left_data, depth-1))
#     127         if right_data[1].shape[0] != 0:
# --> 128             ret.push_right(self.train_node(right_data, depth-1))
#     129         else:
#     130             value, cnt = np.unique(y, return_counts=True)
#
# c:\Users\MLV\OneDrive - UNIST\UNIST\2021_Fall\CSE472_컴퓨터비전\Vision_Framework\models\decisiontree.py in train_node(self, samples, depth)
#     126         ret.push_left(self.train_node(left_data, depth-1))
#     127         if right_data[1].shape[0] != 0:
# --> 128             ret.push_right(self.train_node(right_data, depth-1))
#     129         else:
#     130             value, cnt = np.unique(y, return_counts=True)
#
# c:\Users\MLV\OneDrive - UNIST\UNIST\2021_Fall\CSE472_컴퓨터비전\Vision_Framework\models\decisiontree.py in train_node(self, samples, depth)
#     126         ret.push_left(self.train_node(left_data, depth-1))
#     127         if right_data[1].shape[0] != 0:
# --> 128             ret.push_right(self.train_node(right_data, depth-1))
#     129         else:
#     130             value, cnt = np.unique(y, return_counts=True)
#
# c:\Users\MLV\OneDrive - UNIST\UNIST\2021_Fall\CSE472_컴퓨터비전\Vision_Framework\models\decisiontree.py in train_node(self, samples, depth)
#     126         ret.push_left(self.train_node(left_data, depth-1))
#     127         if right_data[1].shape[0] != 0:
# --> 128             ret.push_right(self.train_node(right_data, depth-1))
#     129         else:
#     130             value, cnt = np.unique(y, return_counts=True)
#
# c:\Users\MLV\OneDrive - UNIST\UNIST\2021_Fall\CSE472_컴퓨터비전\Vision_Framework\models\decisiontree.py in train_node(self, samples, depth)
#     126         ret.push_left(self.train_node(left_data, depth-1))
#     127         if right_data[1].shape[0] != 0:
# --> 128             ret.push_right(self.train_node(right_data, depth-1))
#     129         else:
#     130             value, cnt = np.unique(y, return_counts=True)
#
# c:\Users\MLV\OneDrive - UNIST\UNIST\2021_Fall\CSE472_컴퓨터비전\Vision_Framework\models\decisiontree.py in train_node(self, samples, depth)
#     126         ret.push_left(self.train_node(left_data, depth-1))
#     127         if right_data[1].shape[0] != 0:
# --> 128             ret.push_right(self.train_node(right_data, depth-1))
#     129         else:
#     130             value, cnt = np.unique(y, return_counts=True)
#
# c:\Users\MLV\OneDrive - UNIST\UNIST\2021_Fall\CSE472_컴퓨터비전\Vision_Framework\models\decisiontree.py in train_node(self, samples, depth)
#     126         ret.push_left(self.train_node(left_data, depth-1))
#     127         if right_data[1].shape[0] != 0:
# --> 128             ret.push_right(self.train_node(right_data, depth-1))
#     129         else:
#     130             value, cnt = np.unique(y, return_counts=True)
#
# c:\Users\MLV\OneDrive - UNIST\UNIST\2021_Fall\CSE472_컴퓨터비전\Vision_Framework\models\decisiontree.py in train_node(self, samples, depth)
#     126         ret.push_left(self.train_node(left_data, depth-1))
#     127         if right_data[1].shape[0] != 0:
# --> 128             ret.push_right(self.train_node(right_data, depth-1))
#     129         else:
#     130             value, cnt = np.unique(y, return_counts=True)
#
# c:\Users\MLV\OneDrive - UNIST\UNIST\2021_Fall\CSE472_컴퓨터비전\Vision_Framework\models\decisiontree.py in train_node(self, samples, depth)
#     126         ret.push_left(self.train_node(left_data, depth-1))
#     127         if right_data[1].shape[0] != 0:
# --> 128             ret.push_right(self.train_node(right_data, depth-1))
#     129         else:
#     130             value, cnt = np.unique(y, return_counts=True)
#
# c:\Users\MLV\OneDrive - UNIST\UNIST\2021_Fall\CSE472_컴퓨터비전\Vision_Framework\models\decisiontree.py in train_node(self, samples, depth)
#     126         ret.push_left(self.train_node(left_data, depth-1))
#     127         if right_data[1].shape[0] != 0:
# --> 128             ret.push_right(self.train_node(right_data, depth-1))
#     129         else:
#     130             value, cnt = np.unique(y, return_counts=True)
#
# c:\Users\MLV\OneDrive - UNIST\UNIST\2021_Fall\CSE472_컴퓨터비전\Vision_Framework\models\decisiontree.py in train_node(self, samples, depth)
#     126         ret.push_left(self.train_node(left_data, depth-1))
#     127         if right_data[1].shape[0] != 0:
# --> 128             ret.push_right(self.train_node(right_data, depth-1))
#     129         else:
#     130             value, cnt = np.unique(y, return_counts=True)
#
# c:\Users\MLV\OneDrive - UNIST\UNIST\2021_Fall\CSE472_컴퓨터비전\Vision_Framework\models\decisiontree.py in train_node(self, samples, depth)
#     126         ret.push_left(self.train_node(left_data, depth-1))
#     127         if right_data[1].shape[0] != 0:
# --> 128             ret.push_right(self.train_node(right_data, depth-1))
#     129         else:
#     130             value, cnt = np.unique(y, return_counts=True)
#
# c:\Users\MLV\OneDrive - UNIST\UNIST\2021_Fall\CSE472_컴퓨터비전\Vision_Framework\models\decisiontree.py in train_node(self, samples, depth)
#     126         ret.push_left(self.train_node(left_data, depth-1))
#     127         if right_data[1].shape[0] != 0:
# --> 128             ret.push_right(self.train_node(right_data, depth-1))
#     129         else:
#     130             value, cnt = np.unique(y, return_counts=True)
#
# c:\Users\MLV\OneDrive - UNIST\UNIST\2021_Fall\CSE472_컴퓨터비전\Vision_Framework\models\decisiontree.py in train_node(self, samples, depth)
#     126         ret.push_left(self.train_node(left_data, depth-1))
#     127         if right_data[1].shape[0] != 0:
# --> 128             ret.push_right(self.train_node(right_data, depth-1))
#     129         else:
#     130             value, cnt = np.unique(y, return_counts=True)
#
# c:\Users\MLV\OneDrive - UNIST\UNIST\2021_Fall\CSE472_컴퓨터비전\Vision_Framework\models\decisiontree.py in train_node(self, samples, depth)
#     126         ret.push_left(self.train_node(left_data, depth-1))
#     127         if right_data[1].shape[0] != 0:
# --> 128             ret.push_right(self.train_node(right_data, depth-1))
#     129         else:
#     130             value, cnt = np.unique(y, return_counts=True)
#
# c:\Users\MLV\OneDrive - UNIST\UNIST\2021_Fall\CSE472_컴퓨터비전\Vision_Framework\models\decisiontree.py in train_node(self, samples, depth)
#     126         ret.push_left(self.train_node(left_data, depth-1))
#     127         if right_data[1].shape[0] != 0:
# --> 128             ret.push_right(self.train_node(right_data, depth-1))
#     129         else:
#     130             value, cnt = np.unique(y, return_counts=True)
#
# c:\Users\MLV\OneDrive - UNIST\UNIST\2021_Fall\CSE472_컴퓨터비전\Vision_Framework\models\decisiontree.py in train_node(self, samples, depth)
#     126         ret.push_left(self.train_node(left_data, depth-1))
#     127         if right_data[1].shape[0] != 0:
# --> 128             ret.push_right(self.train_node(right_data, depth-1))
#     129         else:
#     130             value, cnt = np.unique(y, return_counts=True)
#
# c:\Users\MLV\OneDrive - UNIST\UNIST\2021_Fall\CSE472_컴퓨터비전\Vision_Framework\models\decisiontree.py in train_node(self, samples, depth)
#     120             return NODE(func)
#     121
# --> 122         func = self.function_select(X, y)
#     123         left_data, right_data = split_data(X, y, func)
#     124
#
# c:\Users\MLV\OneDrive - UNIST\UNIST\2021_Fall\CSE472_컴퓨터비전\Vision_Framework\models\decisiontree.py in function_select(self, X, y)
#     150                 thres = w * np.random.randint(1, maximum)
#     151                 func = split_linear_func(feature, w, thres)
# --> 152                 info = info_gain(X, y, func)
#     153                 if info > max_info and (info is not np.inf):
#     154                     max_info = info
#
# c:\Users\MLV\OneDrive - UNIST\UNIST\2021_Fall\CSE472_컴퓨터비전\Vision_Framework\models\decisiontree.py in info_gain(X, y, func)
#      61 """
#      62 def info_gain(X, y, func):
# ---> 63     pos, _ = split_data(X, y, func)
#      64
#      65     if pos[1].shape[0] == 0:
#
# c:\Users\MLV\OneDrive - UNIST\UNIST\2021_Fall\CSE472_컴퓨터비전\Vision_Framework\models\decisiontree.py in split_data(X, y, func)
#      32     neg_boolean = np.logical_not(boolean)
#      33     pos = [X[boolean], y[boolean]]
# ---> 34     neg = [X[neg_boolean], y[neg_boolean]]
#      35     return pos, neg
#      36
#
# KeyboardInterrupt:

# %%
prediction, pred = model.predict(trainFeature)

# %%
trainFeature.shape

# %%
boolean = (pred == trainy)
print(np.sum(boolean) / trainy.shape[0] * 100)

# %%
with open("./cluster.dump", "rb") as f:
    cluster = pickle.load(f)
testX, testy = get_data(dataset=args['dataset'], train=False, dataroot=args['dataroot'])
if args['dataset'] == 'cifar10':
    testX = testX.reshape((-1, 32, 32, 3), order='F')
testFeature = get_bow(testX, cluster, num_dict=args['dict_size'])

# %%
pred = model.predict(testFeature)

# %%
boolean = (pred[1] == testy)

# %%
print(np.sum(boolean) / testy.shape[0] * 100)
